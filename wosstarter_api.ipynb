# %%
#install the wosstarter repository from github
# !pip install git+https://github.com/clarivate/wosstarter_python_client.git
# Out:
# Collecting git+https://github.com/clarivate/wosstarter_python_client.git
#   Cloning https://github.com/clarivate/wosstarter_python_client.git to c:\users\shuyuzhang\appdata\local\temp\pip-req-build-5ivq2o09
#   Resolved https://github.com/clarivate/wosstarter_python_client.git to commit c6c05607a6a3ca640da4802e3aa2b295b04279a6
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pydantic>=2 in d:\jianzhuruanjian\anaconda3\lib\site-packages (from clarivate-wos-starter-python-client==1.0.0) (2.6.4)
# Requirement already satisfied: python-dateutil in d:\jianzhuruanjian\anaconda3\lib\site-packages (from clarivate-wos-starter-python-client==1.0.0) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.7.1 in d:\jianzhuruanjian\anaconda3\lib\site-packages (from clarivate-wos-starter-python-client==1.0.0) (4.9.0)
# Requirement already satisfied: urllib3<2.1.0,>=1.25.3 in d:\jianzhuruanjian\anaconda3\lib\site-packages (from clarivate-wos-starter-python-client==1.0.0) (1.26.14)
# Requirement already satisfied: pydantic-core==2.16.3 in d:\jianzhuruanjian\anaconda3\lib\site-packages (from pydantic>=2->clarivate-wos-starter-python-client==1.0.0) (2.16.3)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\jianzhuruanjian\anaconda3\lib\site-packages (from pydantic>=2->clarivate-wos-starter-python-client==1.0.0) (0.6.0)
# Requirement already satisfied: six>=1.5 in d:\jianzhuruanjian\anaconda3\lib\site-packages (from python-dateutil->clarivate-wos-starter-python-client==1.0.0) (1.16.0)
#   Running command git clone --filter=blob:none --quiet https://github.com/clarivate/wosstarter_python_client.git 'C:\Users\ShuyuZhang\AppData\Local\Temp\pip-req-build-5ivq2o09'

# %%
import os
import time
import clarivate.wos_starter.client
from clarivate.wos_starter.client.rest import ApiException
from pprint import pprint

# %%
# Defining the host is optional and defaults to http://api.clarivate.com/apis/wos-starter/v1
# See configuration.py for a list of all supported configuration parameters.
configuration = clarivate.wos_starter.client.Configuration(
    host = "http://api.clarivate.com/apis/wos-starter/v1"
)

# The client must configure the authentication and authorization parameters
# in accordance with the API server security policy.
# Examples for each auth method are provided below, use the example that
# satisfies your auth use case.

# Configure API key authorization: ClarivateApiKeyAuth
configuration.api_key['ClarivateApiKeyAuth'] = "28a0b4969c26f7d9f6f8769351f6fbeba4012746"
# Uncomment below to setup prefix (e.g. Bearer) for API key, if needed
# configuration.api_key_prefix['ClarivateApiKeyAuth'] = 'Bearer'


# Enter a context with an instance of the API client
with clarivate.wos_starter.client.ApiClient(configuration) as api_client:
    # Create an instance of the API class
    api_instance = clarivate.wos_starter.client.DocumentsApi(api_client)
    q = '( ( ( TI= ( govern*  OR  state  OR  decision-making  OR  policy-making OR participat* OR stakeholder ) )  AND  ( TS= ( impact  OR  outcome  OR performance OR  result  OR  differentiation  OR  consequence  OR  change  OR  transformation OR role ) ) )  OR  ( TS= ( governance  NEAR/0  ( mode  OR  model  OR role OR process  )) ) ) AND (TS= ( effect  OR  caus*  OR  explain*  OR  influence  OR  affect  OR  mechanism  OR  restrict  OR  create  OR  impact  OR  drive  OR  role  OR  transform*  OR  relation*  OR  led  OR  improve  OR  interven*  OR  respon* ) ) AND  ( TS= (( urban  OR  neighborhood  OR  city  OR  residential  OR  regional  OR  housing )  NEAR/0 (development  OR  redevelopment OR renewal OR  regeneration  OR  restructuring  OR  revitalization  OR governance ) )  )' # str | Web of Science advanced [advanced search query builder](https://webofscience.help.clarivate.com/en-us/Content/advanced-search.html). The supported field tags are listed in description.
    db = 'WOS' # str | Web of Science Database abbreviation * WOS - Web of Science Core collection * BIOABS - Biological Abstracts * BCI - BIOSIS Citation Index * BIOSIS - BIOSIS Previews * CCC - Current Contents Connect * DIIDW - Derwent Innovations Index * DRCI - Data Citation Index * MEDLINE - MEDLINE The U.S. National Library of Medicine® (NLM®) premier life sciences database. * ZOOREC - Zoological Records * PPRN - Preprint Citation Index * WOK - All databases  (optional) (default to 'WOS')
    limit = 50 # int | set the limit of records on the page (1-50) (optional) (default to 10)
    page = 1 # int | set the result page (optional) (default to 1)
    sort_field = 'LD+D' # str | Order by field(s). Field name and order by clause separated by '+', use A for ASC and D for DESC, ex: PY+D. Multiple values are separated by comma. Supported fields:  * **LD** - Load Date * **PY** - Publication Year * **RS** - Relevance * **TC** - Times Cited  (optional)
    modified_time_span = None # str | Defines a date range in which the results were most recently modified. Beginning and end dates must be specified in the yyyy-mm-dd format separated by '+' or ' ', e.g. 2023-01-01+2023-12-31. This parameter is not compatible with the all databases search, i.e. db=WOK is not compatible with this parameter. (optional)
    tc_modified_time_span = None # str | Defines a date range in which times cited counts were modified. Beginning and end dates must be specified in the yyyy-mm-dd format separated by '+' or ' ', e.g. 2023-01-01+2023-12-31. This parameter is not compatible with the all databases search, i.e. db=WOK is not compatible with this parameter. (optional)
    detail = None # str | it will returns the full data by default, if detail=short it returns the limited data (optional)

try:
    for page in range(1, 5):  # Fetching 4 pages of results
        # Query Web of Science documents 
        api_response = api_instance.documents_get(q, db=db, limit=limit, page=page, sort_field=sort_field, modified_time_span=modified_time_span, tc_modified_time_span=tc_modified_time_span, detail=detail)
        print("The response of DocumentsApi->documents_get (Page {}):\n".format(page))
        pprint(api_response)
        
        # Save the API response to a text file
        with open('api_response_page{}.txt'.format(page), 'w', encoding='utf-8') as f:
            f.write(str(api_response))
            
except ApiException as e:
    print("Exception when calling DocumentsApi->documents_get: %s\n" % e)
# Out:
# The response of DocumentsApi->documents_get (Page 1):
#
# DocumentsList(metadata=Metadata(page=1, limit=50, total=3963), hits=[Document(uid='WOS:001185848500001', title="Phased responses of urban tree canopy cover changes to urbanization process within Beijing's built-up area: An analytical framework coupling state, transition, and drivers", types=['Article'], source_types=['Article'], source=DocumentSource(source_title='ECOLOGICAL INDICATORS', publish_year=2024, publish_month='FEB', volume='159', issue=None, supplement=None, special_issue=None, article_number='111710', pages=DocumentSourcePages(range=None, begin=None, end=None, count=14)), names=DocumentNames(authors=[AuthorName(display_name='Li, Tong', wos_standard='Li, T', researcher_id=None), AuthorName(display_name='Jia, Baoquan', wos_standard='Jia, BQ', researcher_id=None), AuthorName(display_name='Li, Xiaoting', wos_standard='Li, XT', researcher_id=None), AuthorName(display_name='Zhang, Qiumeng', wos_standard='Zhang, QM', researcher_id=None), AuthorName(display_name='Fang, Youxin', wos_standard='Fang, YX', researcher_id=None)], inventors=None, book_corp=None, book_editors=None, books=None, additional_authors=None, anonymous=None, assignees=None, corp=None, editors=None, investigators=None, sponsors=None, issuing_organizations=None), links=DocumentLinks(record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001185848500001&DestLinkType=FullRecord&DestApp=WOS_CPL', citing_articles=None, references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001185848500001&DestLinkType=CitedReferences&DestApp=WOS', related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001185848500001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'), citations=[], identifiers=DocumentIdentifiers(doi='10.1016/j.ecolind.2024.111710', issn='1470-160X', eissn='1872-7034', isbn=None, eisbn=None, pmid=None), keywords=DocumentKeywords(author_keywords=['Urban tree canopy cover', 'Phased changes', 'State', 'Transition', 'Urbanization factors', 'Image interpretation'])), Document(uid='WOS:001184747600001', title='Unveiling citizen-government interactions in urban renewal in China: Spontaneous online opinions, reginal characteristics, and government responsiveness', types=['Article'], source_types=['Article'], source=DocumentSource(source_title='CITIES', publish_year=2024, publish_month='MAY', volume='148', issue=None, supplement=None, special_issue=None, article_number='104857', pages=DocumentSourcePages(range=None, begin=None, end=None, count=16)), names=DocumentNames(authors=[AuthorName(display_name='Shen, Chen', wos_standard='Shen, C', researcher_id=None), AuthorName(display_name='Wang, Yang', wos_standard='Wang, Y', researcher_id=None), AuthorName(display_name='Xu, Yan', wos_standard='Xu, Y', researcher_id=None), AuthorName(display_name='Li, Xiangyu', wos_standard='Li, XY', researcher_id=None)], inventors=None, book_corp=None, book_editors=None, books=None, additional_authors=None, anonymous=None, assignees=None, corp=None, editors=None, investigators=None, sponsors=None, issuing_organizations=None), links=DocumentLinks(record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001184747600001&DestLinkType=FullRecord&DestApp=WOS_CPL', citing_articles=None, references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001184747600001&DestLinkType=CitedReferences&DestApp=WOS', related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001184747600001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'), citations=[], identifiers=DocumentIdentifiers(doi='10.1016/j.cities.2024.104857', issn='0264-2751', eissn='1873-6084', isbn=None, eisbn=None, pmid=None), keywords=DocumentKeywords(author_keywords=['Urban renewal', 'Public opinions', 'Online participation', 'Government responsiveness'])), Document(uid='WOS:001175036 ...
# The response of DocumentsApi->documents_get (Page 2):
#
# DocumentsList(metadata=Metadata(page=2, limit=50, total=3963), hits=[Document(uid='WOS:001148728400008', title='Participatory Budgeting and Placemaking: Concepts, Methods, and Practices', types=['Article'], source_types=['Article'], source=DocumentSource(source_title='URBAN PLANNING', publish_year=2024, publish_month=None, volume='9', issue=None, supplement=None, special_issue=None, article_number='7162', pages=DocumentSourcePages(range=None, begin=None, end=None, count=18)), names=DocumentNames(authors=[AuthorName(display_name='Costa, Carlos Smaniotto', wos_standard='Costa, CS', researcher_id='ACT-1782-2022'), AuthorName(display_name='Garcia-Esparza, Juan A.', wos_standard='García-Esparza, JA', researcher_id='JJL-7643-2023'), AuthorName(display_name='Kimic, Kinga', wos_standard='Kimic, K', researcher_id='AAJ-5523-2021')], inventors=None, book_corp=None, book_editors=None, books=None, additional_authors=None, anonymous=None, assignees=None, corp=None, editors=None, investigators=None, sponsors=None, issuing_organizations=None), links=DocumentLinks(record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001148728400008&DestLinkType=FullRecord&DestApp=WOS_CPL', citing_articles=None, references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001148728400008&DestLinkType=CitedReferences&DestApp=WOS', related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001148728400008&DestLinkType=RelatedRecords&DestApp=WOS_CPL'), citations=[], identifiers=DocumentIdentifiers(doi='10.17645/up.7162', issn='2183-7635', eissn=None, isbn=None, eisbn=None, pmid=None), keywords=DocumentKeywords(author_keywords=['citizen participation', 'community engagement', 'participatory budgeting', 'placemaking', 'Poland', 'Portugal', 'public realm', 'Spain'])), Document(uid='WOS:001148728400007', title='Citizen Participation, Digital Agency, and Urban Development', types=['Editorial material'], source_types=['Editorial Material'], source=DocumentSource(source_title='URBAN PLANNING', publish_year=2024, publish_month=None, volume='9', issue=None, supplement=None, special_issue=None, article_number='7810', pages=DocumentSourcePages(range=None, begin=None, end=None, count=6)), names=DocumentNames(authors=[AuthorName(display_name='Tappert, Simone', wos_standard='Tappert, S', researcher_id='DYV-7961-2022'), AuthorName(display_name='Mehan, Asma', wos_standard='Mehan, A', researcher_id='HGU-6712-2022'), AuthorName(display_name='Tuominen, Pekka', wos_standard='Tuominen, P', researcher_id='HGE-9422-2022'), AuthorName(display_name='Varga, Zsuzsanna', wos_standard='Varga, Z', researcher_id='IYV-5940-2023')], inventors=None, book_corp=None, book_editors=None, books=None, additional_authors=None, anonymous=None, assignees=None, corp=None, editors=None, investigators=None, sponsors=None, issuing_organizations=None), links=DocumentLinks(record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001148728400007&DestLinkType=FullRecord&DestApp=WOS_CPL', citing_articles=None, references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001148728400007&DestLinkType=CitedReferences&DestApp=WOS', related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001148728400007&DestLinkType=RelatedRecords&DestApp=WOS_CPL'), citations=[], identifiers=DocumentIdentifiers(doi='10.17645/up.7810', issn='2183-7635', eissn=None, isbn=None, eisbn=None, pmid=None), keywords=DocumentKeywords(author_keywords=['activism', 'citizen participation', 'digitalisation', 'multi-stakeholder', 'urban development'])), Document(uid='WOS:001145360600001', title='The Spread of MaaS Initiatives in Europe: The Leading Role of Public Governance Emerging from an Italian Regional Application', types=['Article'], source_types=['Article'], source=DocumentSource( ...
# The response of DocumentsApi->documents_get (Page 3):
#
# DocumentsList(metadata=Metadata(page=3, limit=50, total=3963), hits=[Document(uid='WOS:001121532400001', title='Community participation as a premise for<i> hangwurian</i> city development in North Central Nigeria', types=['Article'], source_types=['Article'], source=DocumentSource(source_title='HELIYON', publish_year=2023, publish_month='NOV', volume='9', issue='11', supplement=None, special_issue=None, article_number='e22320', pages=DocumentSourcePages(range=None, begin=None, end=None, count=14)), names=DocumentNames(authors=[AuthorName(display_name='Medayese, Samuel', wos_standard='Medayese, S', researcher_id='FPG-8472-2022'), AuthorName(display_name='Magidimisha-Chipungu, Hangwelani H.', wos_standard='Magidimisha-Chipungu, HH', researcher_id='HWH-1463-2023'), AuthorName(display_name='Chipungu, Lovemore', wos_standard='Chipungu, L', researcher_id='DVO-1313-2022')], inventors=None, book_corp=None, book_editors=None, books=None, additional_authors=None, anonymous=None, assignees=None, corp=None, editors=None, investigators=None, sponsors=None, issuing_organizations=None), links=DocumentLinks(record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001121532400001&DestLinkType=FullRecord&DestApp=WOS_CPL', citing_articles=None, references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001121532400001&DestLinkType=CitedReferences&DestApp=WOS', related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001121532400001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'), citations=[], identifiers=DocumentIdentifiers(doi='10.1016/j.heliyon.2023.e22320', issn=None, eissn='2405-8440', isbn=None, eisbn=None, pmid='38053904'), keywords=DocumentKeywords(author_keywords=['Hangwurian city development', 'Liveability', 'Inclusivity', 'Sustainability', 'Environmental awareness', 'City', 'Governance'])), Document(uid='WOS:001120561700001', title='A Comprehensive Bibliometric Analysis of Urban Renewal Research during 2012-2022', types=['Article'], source_types=['Article'], source=DocumentSource(source_title='BUILDINGS', publish_year=2023, publish_month='NOV', volume='13', issue='11', supplement=None, special_issue=None, article_number='2826', pages=DocumentSourcePages(range=None, begin=None, end=None, count=20)), names=DocumentNames(authors=[AuthorName(display_name='Zhang, Beibei', wos_standard='Zhang, BB', researcher_id='JMP-9315-2023'), AuthorName(display_name='Xiong, Yuxin', wos_standard='Xiong, YX', researcher_id='GHT-5765-2022'), AuthorName(display_name='Liu, Hao', wos_standard='Liu, H', researcher_id='JUE-1313-2023'), AuthorName(display_name='Lyu, Sainan', wos_standard='Lyu, S', researcher_id='FII-3096-2022'), AuthorName(display_name='Skitmore, Martin', wos_standard='Skitmore, M', researcher_id='I-9743-2012')], inventors=None, book_corp=None, book_editors=None, books=None, additional_authors=None, anonymous=None, assignees=None, corp=None, editors=None, investigators=None, sponsors=None, issuing_organizations=None), links=DocumentLinks(record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001120561700001&DestLinkType=FullRecord&DestApp=WOS_CPL', citing_articles=None, references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001120561700001&DestLinkType=CitedReferences&DestApp=WOS', related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001120561700001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'), citations=[], identifiers=DocumentIdentifiers(doi='10.3390/buildings13112826', issn=None, eissn='2075-5309', isbn=None, eisbn=None, pmid=None), keywords=DocumentKeywords(author_keywords=['urban renewal', 'sustainable development', 'bibliometric analysis', 'visualization'])), Document(uid='WOS:001115266000001', title="Good Governance, Resilience, and Sustainable Development: A Combi ...
# The response of DocumentsApi->documents_get (Page 4):
#
# DocumentsList(metadata=Metadata(page=4, limit=50, total=3963), hits=[Document(uid='WOS:001086757100001', title='Action-oriented planning methods as a tool for improving regional governance in Switzerland: Evidence from the Sisslerfeld area', types=['Article'], source_types=['Article'], source=DocumentSource(source_title='LAND USE POLICY', publish_year=2023, publish_month='NOV', volume='134', issue=None, supplement=None, special_issue=None, article_number='106927', pages=DocumentSourcePages(range=None, begin=None, end=None, count=16)), names=DocumentNames(authors=[AuthorName(display_name='Papamichail, Theodora', wos_standard='Papamichail, T', researcher_id='DJQ-0959-2022'), AuthorName(display_name='Peric, Ana', wos_standard='Peric, A', researcher_id='J-8749-2019')], inventors=None, book_corp=None, book_editors=None, books=None, additional_authors=None, anonymous=None, assignees=None, corp=None, editors=None, investigators=None, sponsors=None, issuing_organizations=None), links=DocumentLinks(record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001086757100001&DestLinkType=FullRecord&DestApp=WOS_CPL', citing_articles=None, references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001086757100001&DestLinkType=CitedReferences&DestApp=WOS', related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001086757100001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'), citations=[], identifiers=DocumentIdentifiers(doi='10.1016/j.landusepol.2023.106927', issn='0264-8377', eissn='1873-5754', isbn=None, eisbn=None, pmid=None), keywords=DocumentKeywords(author_keywords=['Spatial development', 'Regional governance', 'Regional planning', 'Spatial visioning', 'Collaboration', 'Test planning method', 'Switzerland'])), Document(uid='WOS:001086141600001', title='Neoliberal urban development and the polarization of urban governance', types=['Article'], source_types=['Article'], source=DocumentSource(source_title='CITIES', publish_year=2023, publish_month='DEC', volume='143', issue=None, supplement=None, special_issue=None, article_number='104570', pages=DocumentSourcePages(range=None, begin=None, end=None, count=5)), names=DocumentNames(authors=[AuthorName(display_name='Baffoe, Gideon', wos_standard='Baffoe, G', researcher_id='GCG-3596-2022')], inventors=None, book_corp=None, book_editors=None, books=None, additional_authors=None, anonymous=None, assignees=None, corp=None, editors=None, investigators=None, sponsors=None, issuing_organizations=None), links=DocumentLinks(record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001086141600001&DestLinkType=FullRecord&DestApp=WOS_CPL', citing_articles=None, references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001086141600001&DestLinkType=CitedReferences&DestApp=WOS', related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=slr2024&SrcAuth=WosAPI&KeyUT=WOS:001086141600001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'), citations=[], identifiers=DocumentIdentifiers(doi='10.1016/j.cities.2023.104570', issn='0264-2751', eissn='1873-6084', isbn=None, eisbn=None, pmid=None), keywords=DocumentKeywords(author_keywords=['Urbanization', 'Governance', 'Urban development', 'Planning', 'Neoliberalism'])), Document(uid='WOS:001086710800001', title="Dataset on Bac settlement stakeholders' perspectives on integrative urban design play as an instrument for managing wicked urban regeneration issues in sustainable way", types=['Article', 'Data Paper'], source_types=['Article', 'Data Paper'], source=DocumentSource(source_title='DATA IN BRIEF', publish_year=2023, publish_month='OCT', volume='50', issue=None, supplement=None, special_issue=None, article_number='109562', pages=DocumentSourcePages(range=None, begin=None, end=None, count=16)), names=DocumentNames(authors=[AuthorName(display ...
